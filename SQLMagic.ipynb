# %%
# %load_ext sql

# %%
# %%sql
# postgresql://postgres:K@trina26@localhost/postgres
# Out:
# 'Connected: postgres@postgres'

# %%
# %%sql
# SELECT version();
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [('PostgreSQL 11.0, compiled by Visual C++ build 1914, 64-bit',)]

# %%
# %%sql
# CREATE DATABASE dvdrental;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# (psycopg2.ProgrammingError) database "dvdrental" already exists
#  [SQL: 'CREATE DATABASE dvdrental;'] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
# postgresql://postgres:K@trina26@localhost/dvdrental
# Out:
# 'Connected: postgres@dvdrental'

# %%
# %%sql
# SELECT * FROM customer;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 599 rows affected.
# [(524, 1, 'Jared', 'Ely', 'jared.ely@sakilacustomer.org', 530, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (1, 1, 'Mary', 'Smith', 'mary.smith@sakilacustomer.org', 5, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (2, 1, 'Patricia', 'Johnson', 'patricia.johnson@sakilacustomer.org', 6, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (3, 1, 'Linda', 'Williams', 'linda.williams@sakilacustomer.org', 7, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
#  (4, 2, 'Barbara', 'Jones', 'barbara.jones@sakilacustomer.org', 8, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1),
# ...

# %%
result = _

# %%
result = %sql SELECT * FROM customer
print(result.keys)
print(result[0].email)
print(result[0][2])
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 599 rows affected.
# ['customer_id', 'store_id', 'first_name', 'last_name', 'email', 'address_id', 'activebool', 'create_date', 'last_update', 'active']
# jared.ely@sakilacustomer.org
# Jared

# %%
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = result.DataFrame()
df.groupby('active')
plt.scatter(df.store_id, df.customer_id)#df.x, df.y #viz makes no sense i know just testing it out

# %%
# %%sql
# SELECT first_name,last_name,email FROM customer;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 599 rows affected.
# [('Jared', 'Ely', 'jared.ely@sakilacustomer.org'),
#  ('Mary', 'Smith', 'mary.smith@sakilacustomer.org'),
#  ('Patricia', 'Johnson', 'patricia.johnson@sakilacustomer.org'),
#  ('Linda', 'Williams', 'linda.williams@sakilacustomer.org'),
#  ('Barbara', 'Jones', 'barbara.jones@sakilacustomer.org'),
#  ('Elizabeth', 'Brown', 'elizabeth.brown@sakilacustomer.org'),
#  ('Jennifer', 'Davis', 'jennifer.davis@sakilacustomer.org'),
#  ('Maria', 'Miller', 'maria.miller@sakilacustomer.org'),
#  ('Susan', 'Wilson', 'susan.wilson@sakilacustomer.org'),
#  ('Margaret', 'Moore', 'margaret.moore@sakilacustomer.org'),
#  ('Dorothy', 'Taylor', 'dorothy.taylor@sakilacustomer.org'),
#  ('Lisa', 'Anderson', 'lisa.anderson@sakilacustomer.org'),
#  ('Nancy', 'Thomas', 'nancy.thomas@sakilacustomer.org'),
#  ('Karen', 'Jackson', 'karen.jackson@sakilacustomer.org'),
# ...

# %%
# %%sql
# select user;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [('postgres',)]

# %%
# %%sql
# select 5;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [(5,)]

# %%
# %%sql
# select sqrt(4.0);
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [(Decimal('2.000000000000000'),)]

# %%
# %%sql
# select timeofday();
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [('Wed Nov 21 00:49:38.921319 2018 EAT',)]

# %%
# %%sql
# select now();
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [(datetime.datetime(2018, 11, 21, 0, 49, 45, 752021, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=180, name=None)),)]

# %%
# %%sql
# select timeofday(),now();
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [('Wed Nov 21 00:49:51.717424 2018 EAT', datetime.datetime(2018, 11, 21, 0, 49, 51, 717301, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=180, name=None)))]

# %%
# %%sql
# select first_name, last_name from customer order by first_name asc;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 599 rows affected.
# [('Aaron', 'Selby'),
#  ('Adam', 'Gooch'),
#  ('Adrian', 'Clary'),
#  ('Agnes', 'Bishop'),
#  ('Alan', 'Kahn'),
#  ('Albert', 'Crouse'),
#  ('Alberto', 'Henning'),
#  ('Alex', 'Gresham'),
#  ('Alexander', 'Fennell'),
#  ('Alfred', 'Casillas'),
#  ('Alfredo', 'Mcadams'),
#  ('Alice', 'Stewart'),
#  ('Alicia', 'Mills'),
#  ('Allan', 'Cornish'),
#  ('Allen', 'Butterfield'),
#  ('Allison', 'Stanley'),
#  ('Alma', 'Austin'),
#  ('Alvin', 'Deloach'),
#  ('Amanda', 'Carter'),
#  ('Amber', 'Dixon'),
#  ('Amy', 'Lopez'),
#  ('Ana', 'Bradley'),
#  ('Andre', 'Rapp'),
#  ('Andrea', 'Henderson'),
#  ('Andrew', 'Purdy'),
#  ('Andy', 'Vanhorn'),
#  ('Angel', 'Barclay'),
#  ('Angela', 'Hernandez'),
#  ('Anita', 'Morales'),
#  ('Ann', 'Evans'),
#  ('Anna', 'Hill'),
#  ('Anne', 'Powell'),
#  ('Annette', 'Olson'),
#  ('Annie', 'Russell'),
#  ('Anthony', 'Schwab'),
# ...

# %%
# %%sql
# select first_name, last_name from customer order by last_name desc;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 599 rows affected.
# [('Cynthia', 'Young'),
#  ('Marvin', 'Yee'),
#  ('Luis', 'Yanez'),
#  ('Brian', 'Wyman'),
#  ('Brenda', 'Wright'),
#  ('Tyler', 'Wren'),
#  ('Florence', 'Woods'),
#  ('Lori', 'Wood'),
#  ('Virgil', 'Wofford'),
#  ('Darren', 'Windham'),
#  ('Susan', 'Wilson'),
#  ('Bernice', 'Willis'),
#  ('Gina', 'Williamson'),
#  ('Linda', 'Williams'),
#  ('Jon', 'Wiles'),
#  ('Roy', 'Whiting'),
#  ('Betty', 'White'),
#  ('Lucy', 'Wheeler'),
#  ('Fred', 'Wheat'),
#  ('Mitchell', 'Westmoreland'),
#  ('Edna', 'West'),
#  ('Sheila', 'Wells'),
#  ('Marlene', 'Welch'),
#  ('Ronald', 'Weiner'),
#  ('Ethel', 'Webb'),
#  ('Yolanda', 'Weaver'),
#  ('Mike', 'Way'),
#  ('Jamie', 'Waugh'),
#  ('Shelly', 'Watts'),
#  ('Theresa', 'Watson'),
#  ('Yvonne', 'Watkins'),
#  ('Ruby', 'Washington'),
#  ('Hazel', 'Warren'),
#  ('Janice', 'Ward'),
#  ('Cassandra', 'Walters'),
#  ('Connie', 'Wallace'),
# ...

# %%
# %%sql
# select first_name, last_name from customer order by first_name asc, last_name desc;#notice the kelly(s) ordering
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 599 rows affected.
# (psycopg2.ProgrammingError) syntax error at or near "#"
# LINE 1: #notice the kelly(s) ordering
#         ^
#  [SQL: '#notice the kelly(s) ordering'] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# Null is always considered larger than all other values when evaluating ORDER BY clause

# %%
#The DISTINCT clause removes duplicate rows, not duplicate column values

# %%
# %%sql
# create table t1(
# id serial not null primary key,
# bcolor varchar,fcolor varchar
# );
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# (psycopg2.ProgrammingError) relation "t1" already exists
#  [SQL: 'create table t1(\nid serial not null primary key,\nbcolor varchar,fcolor varchar\n);'] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
# insert into t1(bcolor, fcolor)
# values
#  ('red', 'red'),
#  ('red', 'red'),
#  ('red', NULL),
#  (NULL, 'red'),
#  ('red', 'green'),
#  ('red', 'blue'),
#  ('green', 'red'),
#  ('green', 'blue'),
#  ('green', 'green'),
#  ('blue', 'red'),
#  ('blue', 'green'),
#  ('blue', 'blue');
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 12 rows affected.
# []

# %%
# %%sql
# select id, bcolor, fcolor from t1;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 24 rows affected.
# [(1, 'red', 'red'),
#  (2, 'red', 'red'),
#  (3, 'red', None),
#  (4, None, 'red'),
#  (5, 'red', 'green'),
#  (6, 'red', 'blue'),
#  (7, 'green', 'red'),
#  (8, 'green', 'blue'),
#  (9, 'green', 'green'),
#  (10, 'blue', 'red'),
#  (11, 'blue', 'green'),
#  (12, 'blue', 'blue'),
#  (13, 'red', 'red'),
#  (14, 'red', 'red'),
#  (15, 'red', None),
#  (16, None, 'red'),
#  (17, 'red', 'green'),
#  (18, 'red', 'blue'),
#  (19, 'green', 'red'),
#  (20, 'green', 'blue'),
#  (21, 'green', 'green'),
#  (22, 'blue', 'red'),
#  (23, 'blue', 'green'),
#  (24, 'blue', 'blue')]

# %%
# %%sql
# select distinct bcolor from t1 order by bcolor;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 4 rows affected.
# [('blue',), ('green',), ('red',), (None,)]

# %%
# %%sql
# select distinct bcolor, fcolor from t1 order by bcolor, fcolor;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 11 rows affected.
# [('blue', 'blue'),
#  ('blue', 'green'),
#  ('blue', 'red'),
#  ('green', 'blue'),
#  ('green', 'green'),
#  ('green', 'red'),
#  ('red', 'blue'),
#  ('red', 'green'),
#  ('red', 'red'),
#  ('red', None),
#  (None, 'red')]

# %%
# %%sql
# select distinct on (bcolor) bcolor, fcolor from t1 order by bcolor, fcolor;
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 4 rows affected.
# [('blue', 'blue'), ('green', 'blue'), ('red', 'blue'), (None, 'red')]

# %%
# %%sql
# --Comments go here--
# select now()
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 1 rows affected.
# [(datetime.datetime(2018, 11, 21, 0, 51, 32, 705559, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=180, name=None)),)]

# %%
# %%sql
# Select first_name, last_name from customer where first_name = 'Jamie';
# Out:
#  * postgresql://postgres:***@localhost/dvdrental
#    postgresql://postgres:***@localhost/postgres
# 2 rows affected.
# [('Jamie', 'Rice'), ('Jamie', 'Waugh')]
